# %% [markdown]
# # Day 10 - Syntax Scoring
# Corrupted Line - False Closing Bracket
# Incomplete Line - Missing Closing Bracket

# %% [markdown]
# ## Part 1

# %%
open_to_close = {
    "(": ")",
    "[": "]",
    "{": "}",
    "<": ">",
}

bracket_points = {
    ")": 3,
    "]": 57,
    "}": 1197,
    ">": 25137,
}

# %%
def calculate_syntax_score(input_file):
    with open(input_file, "r") as f:
        lines = f.readlines()
    
    score = 0
    for i, line in enumerate(lines):
        # print(f"Processing line: {line.strip()}")
        stack = list(line[0])
        for current in line.strip()[1:]:
            # print(stack, current)
            
            if len(stack) > 0:
                head = stack[-1]
                
                try:
                    closing_bracket = open_to_close[head]
                except KeyError:
                    print(f"Invalid closing bracket for line {i}: {head} {current}")
                    score += bracket_points[head]
                    break
                
                if current == closing_bracket:
                    pass
                    # print(f"Closing {current}")
                    # print("Removing", head)
                    stack.pop()
                else:
                    # print(f"Opening {current}")
                    stack.append(current)
            else:
                stack.append(current)
        
    print(f"Syntax Score: {score}")

# %%
calculate_syntax_score("10_input.in")
# Out:
# Invalid closing bracket for line 4: ] {
# Invalid closing bracket for line 6: > {
# Invalid closing bracket for line 7: > ]
# Invalid closing bracket for line 13: ) >
# Invalid closing bracket for line 14: ) )
# Invalid closing bracket for line 16: } )
# Invalid closing bracket for line 17: ) (
# Invalid closing bracket for line 19: } )
# Invalid closing bracket for line 20: > (
# Invalid closing bracket for line 21: > }
# Invalid closing bracket for line 22: } >
# Invalid closing bracket for line 24: ] {
# Invalid closing bracket for line 27: } <
# Invalid closing bracket for line 31: ] )
# Invalid closing bracket for line 34: > (
# Invalid closing bracket for line 35: > )
# Invalid closing bracket for line 36: > ]
# Invalid closing bracket for line 39: > }
# Invalid closing bracket for line 42: > )
# Invalid closing bracket for line 43: ] [
# Invalid closing bracket for line 44: ] ]
# Invalid closing bracket for line 46: > >
# Invalid closing bracket for line 47: } }
# Invalid closing bracket for line 49: ] >
# Invalid closing bracket for line 50: ] <
# Invalid closing bracket for line 52: ] [
# Invalid closing bracket for line 56: ) (
# Invalid closing bracket for line 58: ] }
# Invalid closing bracket for line 60: } [
# Invalid closing bracket for line 62: } [
# Invalid closing bracket for line 63: ] [
# Invalid closing bracket for line 64: > {
# Invalid closing bracket for line 65: ] <
# Invalid closing bracket for line 66: } >
# Invalid closing bracket for line 67: ) }
# Invalid closing bracket for line 70: ) ]
# Invalid closing bracket for line 74: ) (
# Invalid closing bracket for line 78: } )
# Invalid closing bracket for line 80: } (
# Invalid closing bracket for line 83: ] <
# Invalid closing bracket for line 84: ] >
# Invalid closing bracket for line 85: > [
# Invalid closing bracket for line 88: ) <
# Invalid closing bracket for line 89: } <
# Invalid closing bracket for line 90: ] )
# Invalid closing bracket for line 91: ] ]
# Invalid closing bracket for line 93: ) (
# Syntax Score: 315693

# %% [markdown]
# ## Part 2

# %%
open_to_close = {
    "(": ")",
    "[": "]",
    "{": "}",
    "<": ">",
}

autocomplete_points = {
    ")": 1,
    "]": 2,
    "}": 3,
    ">": 4,
}

# %%
def calculate_autocomplete_score(input_file):
    with open(input_file, "r") as f:
        lines = f.readlines()
    
    line_scores = []
    for i, line in enumerate(lines):
        score = 0
        print(f"Processing line: {line.strip()}")
        stack = list(line[0])
        
        characters = list(line.strip()[1:])
        while characters:
            current = characters.pop(0)
            stack.append(current)
            if len(stack) > 1:
                previous = stack[-2]
                
                # This is a closing bracket.
                if current not in open_to_close:
                    # This is a matching close bracket.
                    if open_to_close[previous] == current:
                        stack.pop()
                        stack.pop()
                    # This is an invalid bracket.
                    else:
                        break

            if len(characters) == 0 and len(stack) != 0:
                print(f"> Incomplete line {i}: {len(stack)} {stack}")
                missing_closing = open_to_close[stack[-1]]
                score *= 5
                score += autocomplete_points[missing_closing]
                characters.append(missing_closing)

        line_scores.append(score)
    
    line_scores = [score for score in line_scores if score != 0]
    line_scores.sort()
    middle_index = (len(line_scores)-1) // 2
    return line_scores[middle_index]

# %%
calculate_autocomplete_score("10_input.in")
# Out:
# Processing line: ([{{(([{<<([<[{}{}][{}<>]>{(()())(<>)}]{[(()[])<[][]>]<[()[]]<{}<>>>}){{<<[]<>>(()[])>{({}(
# > Incomplete line 0: 15 ['(', '[', '{', '{', '(', '(', '[', '{', '<', '<', '{', '{', '{', '(', '(']
# > Incomplete line 0: 14 ['(', '[', '{', '{', '(', '(', '[', '{', '<', '<', '{', '{', '{', '(']
# > Incomplete line 0: 13 ['(', '[', '{', '{', '(', '(', '[', '{', '<', '<', '{', '{', '{']
# > Incomplete line 0: 12 ['(', '[', '{', '{', '(', '(', '[', '{', '<', '<', '{', '{']
# > Incomplete line 0: 11 ['(', '[', '{', '{', '(', '(', '[', '{', '<', '<', '{']
# > Incomplete line 0: 10 ['(', '[', '{', '{', '(', '(', '[', '{', '<', '<']
# > Incomplete line 0: 9 ['(', '[', '{', '{', '(', '(', '[', '{', '<']
# > Incomplete line 0: 8 ['(', '[', '{', '{', '(', '(', '[', '{']
# > Incomplete line 0: 7 ['(', '[', '{', '{', '(', '(', '[']
# > Incomplete line 0: 6 ['(', '[', '{', '{', '(', '(']
# > Incomplete line 0: 5 ['(', '[', '{', '{', '(']
# > Incomplete line 0: 4 ['(', '[', '{', '{']
# > Incomplete line 0: 3 ['(', '[', '{']
# > Incomplete line 0: 2 ['(', '[']
# > Incomplete line 0: 1 ['(']
# Processing line: {<({[{[({(<[({[][]}(()<>))(({}<>)<()[]>)][<{{}[]}[{}()]><[(){}][<><>]>]><{{({}<>){<><>}}[(<><
# > Incomplete line 1: 15 ['{', '<', '(', '{', '[', '{', '[', '(', '{', '(', '<', '{', '[', '(', '<']
# > Incomplete line 1: 14 ['{', '<', '(', '{', '[', '{', '[', '(', '{', '(', '<', '{', '[', '(']
# > Incomplete line 1: 13 ['{', '<', '(', '{', '[', '{', '[', '(', '{', '(', '<', '{', '[']
# > Incomplete line 1: 12 ['{', '<', '(', '{', '[', '{', '[', '(', '{', '(', '<', '{']
# > Incomplete line 1: 11 ['{', '<', '(', '{', '[', '{', '[', '(', '{', '(', '<']
# > Incomplete line 1: 10 ['{', '<', '(', '{', '[', '{', '[', '(', '{', '(']
# > Incomplete line 1: 9 ['{', '<', '(', '{', '[', '{', '[', '(', '{']
# > Incomplete line 1: 8 ['{', '<', '(', '{', '[', '{', '[', '(']
# > Incomplete line 1: 7 ['{', '<', '(', '{', '[', '{', '[']
# > Incomplete line 1: 6 ['{', '<', '(', '{', '[', '{']
# > Incomplete line 1: 5 ['{', '<', '(', '{', '[']
# > Incomplete line 1: 4 ['{', '<', '(', '{']
# > Incomplete line 1: 3 ['{', '<', '(']
# > Incomplete line 1: 2 ['{', '<']
# > Incomplete line 1: 1 ['{']
# Processing line: <{({{{{{{<[([([]<>)]{({}())<()()>})]<[([<>[]][()[]]){[(){}]<[]{}>}]{<[<>{}][(){}]><{[][]}{<><>}>}>>}<<
# > Incomplete line 2: 10 ['<', '{', '(', '{', '{', '{', '{', '{', '<', '<']
# > Incomplete line 2: 9 ['<', '{', '(', '{', '{', '{', '{', '{', '<']
# > Incomplete line 2: 8 ['<', '{', '(', '{', '{', '{', '{', '{']
# > Incomplete line 2: 7 ['<', '{', '(', '{', '{', '{', '{']
# > Incomplete line 2: 6 ['<', '{', '(', '{', '{', '{']
# > Incomplete line 2: 5 ['<', '{', '(', '{', '{']
# > Incomplete line 2: 4 ['<', '{', '(', '{']
# > Incomplete line 2: 3 ['<', '{', '(']
# > Incomplete line 2: 2 ['<', '{']
# > Incomplete line 2: 1 ['<']
# Processing line: ([([{[[{{[((((()[]))<[()<>]{(){}}>))[[({()()}{[][]})(({}[])(<>{}))][{<(){}><(){}>}]]]<[[{[<>[]]}
# > Incomplete line 3: 12 ['(', '[', '(', '[', '{', '[', '[', '{', '{', '<', '[', '[']
# > Incomplete line 3: 11 ['(', '[', '(', '[', '{', '[', '[', '{', '{', '<', '[']
# > Incomplete line 3: 10 ['(', '[', '(', '[', '{', '[', '[', '{', '{', '<']
# > Incomplete line 3: 9 ['(', '[', '(', '[', '{', '[', '[', '{', '{']
# > Incomplete line 3: 8 ['(', '[', '(', '[', '{', '[', '[', '{']
# > Incomplete line 3: 7 ['(', '[', '(', '[', '{', '[', '[']
# > Incomplete line 3: 6 ['(', '[', '(', '[', '{', '[']
# > Incomplete line 3: 5 ['(', '[', '(', '[', '{']
# > Incomplete line 3: 4 ['(', '[', '(', '[']
# > Incomplete line 3: 3 ['(', '[', '(']
# > Incomplete line 3: 2 ['(', '[']
# > Incomplete line 3: 1 ['(']
# Processing line: {{[{{{<(([{[<{[]{}}<[]{}>>([<>[]][{}[]])]<[(<>[])[<>[]]]({[]<>]{()<>})>}{{<<[]()>[<>[]]>({()<>}<[]<>>)}[
# Processing line: <<{[<[<<[{[[<<<>[]>[[][]]>]]}]>[({[[{([]<>){[]()}}{{()<>}[{}()]}][[(()<>)(<>{})]{[<><>]({}<
# > Incomplete line 5: 15 ['<', '<', '{', '[', '<', '[', '<', '[', '(', '{', '[', '[', '{', '(', '<']
# > Incomplete line 5: 14 ['<', '<', '{', '[', '<', '[', '<', '[', '(', '{', '[', '[', '{', '(']
# > Incomplete line 5: 13 ['<', '<', '{', '[', '<', '[', '<', '[', '(', '{', '[', '[', '{']
# > Incomplete line 5: 12 ['<', '<', '{', '[', '<', '[', '<', '[', '(', '{', '[', '[']
# > Incomplete line 5: 11 ['<', '<', '{', '[', '<', '[', '<', '[', '(', '{', '[']
# > Incomplete line 5: 10 ['<', '<', '{', '[', '<', '[', '<', '[', '(', '{']
# > Incomplete line 5: 9 ['<', '<', '{', '[', '<', '[', '<', '[', '(']
# > Incomplete line 5: 8 ['<', '<', '{', '[', '<', '[', '<', '[']
# > Incomplete line 5: 7 ['<', '<', '{', '[', '<', '[', '<']
# > Incomplete line 5: 6 ['<', '<', '{', '[', '<', '[']
# > Incomplete line 5: 5 ['<', '<', '{', '[', '<']
# > Incomplete line 5: 4 ['<', '<', '{', '[']
# > Incomplete line 5: 3 ['<', '<', '{']
# > Incomplete line 5: 2 ['<', '<']
# > Incomplete line 5: 1 ['<']
# Processing line: {[[<<({<[[[<[[<>{}]{{}[]}]<(<>())>>]]>{<{{<[{}[]][<>[]]>[(<><>)<(){}>]}<(<{}[]><{}()>)([()<>]
# Processing line: ([<({<(<{[<<<({}{})({})>((()()))>[(<[]{}>{[]()}>]>]}([({<<<>[]>[{}()]><{[]()}(<>[])>})[([[[][]][[]()]]({()}
# Processing line: [{<{<<{[<({{{[[]()]<[]{}>}(<(){}>([]{}))}}[[<<[]()>{()<>}>]{[<()>({}{})]({<><>}([]{}))}])[<[<
# > Incomplete line 8: 13 ['[', '{', '<', '{', '<', '<', '{', '[', '<', '[', '<', '[', '<']
# > Incomplete line 8: 12 ['[', '{', '<', '{', '<', '<', '{', '[', '<', '[', '<', '[']
# > Incomplete line 8: 11 ['[', '{', '<', '{', '<', '<', '{', '[', '<', '[', '<']
# > Incomplete line 8: 10 ['[', '{', '<', '{', '<', '<', '{', '[', '<', '[']
# > Incomplete line 8: 9 ['[', '{', '<', '{', '<', '<', '{', '[', '<']
# > Incomplete line 8: 8 ['[', '{', '<', '{', '<', '<', '{', '[']
# > Incomplete line 8: 7 ['[', '{', '<', '{', '<', '<', '{']
# > Incomplete line 8: 6 ['[', '{', '<', '{', '<', '<']
# > Incomplete line 8: 5 ['[', '{', '<', '{', '<']
# > Incomplete line 8: 4 ['[', '{', '<', '{']
# > Incomplete line 8: 3 ['[', '{', '<']
# > Incomplete line 8: 2 ['[', '{']
# > Incomplete line 8: 1 ['[']
# Processing line: ({<<<{<[[(<[<[[][]]([]<>)><{<>{}}[{}{}]>]>{[<[{}]>({[][]}<()()>)]<[{<>[]}[[]{}]]>}){[<[(())<{}{}>]<(<>())[[]{
# > Incomplete line 9: 15 ['(', '{', '<', '<', '<', '{', '<', '[', '[', '{', '[', '<', '<', '[', '{']
# > Incomplete line 9: 14 ['(', '{', '<', '<', '<', '{', '<', '[', '[', '{', '[', '<', '<', '[']
# > Incomplete line 9: 13 ['(', '{', '<', '<', '<', '{', '<', '[', '[', '{', '[', '<', '<']
# > Incomplete line 9: 12 ['(', '{', '<', '<', '<', '{', '<', '[', '[', '{', '[', '<']
# > Incomplete line 9: 11 ['(', '{', '<', '<', '<', '{', '<', '[', '[', '{', '[']
# > Incomplete line 9: 10 ['(', '{', '<', '<', '<', '{', '<', '[', '[', '{']
# > Incomplete line 9: 9 ['(', '{', '<', '<', '<', '{', '<', '[', '[']
# > Incomplete line 9: 8 ['(', '{', '<', '<', '<', '{', '<', '[']
# > Incomplete line 9: 7 ['(', '{', '<', '<', '<', '{', '<']
# > Incomplete line 9: 6 ['(', '{', '<', '<', '<', '{']
# > Incomplete line 9: 5 ['(', '{', '<', '<', '<']
# > Incomplete line 9: 4 ['(', '{', '<', '<']
# > Incomplete line 9: 3 ['(', '{', '<']
# > Incomplete line 9: 2 ['(', '{']
# > Incomplete line 9: 1 ['(']
# Processing line: <(<<(({<<[((<[[]()]{{}{}}>[<<>{}>([]<>)]){{<[]<>>([]<>)}<([]())<{}>>})<[[(()())]([{}()](<>
# > Incomplete line 10: 14 ['<', '(', '<', '<', '(', '(', '{', '<', '<', '[', '<', '[', '(', '(']
# > Incomplete line 10: 13 ['<', '(', '<', '<', '(', '(', '{', '<', '<', '[', '<', '[', '(']
# > Incomplete line 10: 12 ['<', '(', '<', '<', '(', '(', '{', '<', '<', '[', '<', '[']
# > Incomplete line 10: 11 ['<', '(', '<', '<', '(', '(', '{', '<', '<', '[', '<']
# > Incomplete line 10: 10 ['<', '(', '<', '<', '(', '(', '{', '<', '<', '[']
# > Incomplete line 10: 9 ['<', '(', '<', '<', '(', '(', '{', '<', '<']
# > Incomplete line 10: 8 ['<', '(', '<', '<', '(', '(', '{', '<']
# > Incomplete line 10: 7 ['<', '(', '<', '<', '(', '(', '{']
# > Incomplete line 10: 6 ['<', '(', '<', '<', '(', '(']
# > Incomplete line 10: 5 ['<', '(', '<', '<', '(']
# > Incomplete line 10: 4 ['<', '(', '<', '<']
# > Incomplete line 10: 3 ['<', '(', '<']
# > Incomplete line 10: 2 ['<', '(']
# > Incomplete line 10: 1 ['<']
# Processing line: [[<{([({[{{{<{()()}{{}{}}>{[[]<>](()())}}}<[<(<><>)(<><>)>{{{}<>}(<>())}]{(<<>()>([]{}))({()<>}[<>{}])}
# > Incomplete line 11: 11 ['[', '[', '<', '{', '(', '[', '(', '{', '[', '{', '<']
# > Incomplete line 11: 10 ['[', '[', '<', '{', '(', '[', '(', '{', '[', '{']
# > Incomplete line 11: 9 ['[', '[', '<', '{', '(', '[', '(', '{', '[']
# > Incomplete line 11: 8 ['[', '[', '<', '{', '(', '[', '(', '{']
# > Incomplete line 11: 7 ['[', '[', '<', '{', '(', '[', '(']
# > Incomplete line 11: 6 ['[', '[', '<', '{', '(', '[']
# > Incomplete line 11: 5 ['[', '[', '<', '{', '(']
# > Incomplete line 11: 4 ['[', '[', '<', '{']
# > Incomplete line 11: 3 ['[', '[', '<']
# > Incomplete line 11: 2 ['[', '[']
# > Incomplete line 11: 1 ['[']
# Processing line: <{{(<<{{([<[<{()[]}>][<<{}<>>>[([]<>)({}[])]]>])}<{(<<([[]{}])<[[]{}]{{}{}}>><{{(){}}<()<>>}([{}{}][
# > Incomplete line 12: 14 ['<', '{', '{', '(', '<', '<', '{', '<', '{', '(', '<', '<', '(', '[']
# > Incomplete line 12: 13 ['<', '{', '{', '(', '<', '<', '{', '<', '{', '(', '<', '<', '(']
# > Incomplete line 12: 12 ['<', '{', '{', '(', '<', '<', '{', '<', '{', '(', '<', '<']
# > Incomplete line 12: 11 ['<', '{', '{', '(', '<', '<', '{', '<', '{', '(', '<']
# > Incomplete line 12: 10 ['<', '{', '{', '(', '<', '<', '{', '<', '{', '(']
# > Incomplete line 12: 9 ['<', '{', '{', '(', '<', '<', '{', '<', '{']
# > Incomplete line 12: 8 ['<', '{', '{', '(', '<', '<', '{', '<']
# > Incomplete line 12: 7 ['<', '{', '{', '(', '<', '<', '{']
# > Incomplete line 12: 6 ['<', '{', '{', '(', '<', '<']
# > Incomplete line 12: 5 ['<', '{', '{', '(', '<']
# > Incomplete line 12: 4 ['<', '{', '{', '(']
# > Incomplete line 12: 3 ['<', '{', '{']
# > Incomplete line 12: 2 ['<', '{']
# > Incomplete line 12: 1 ['<']
# Processing line: [[<(([{((<{([{{}<>}[<>[]]]<[()()]<[][])>)}[<{[[]]<{}<>>}([<><>]{[][]})>]>(<[<<<><>>>(<<>{}>
# Processing line: {{{{[[<<<{{<({{}}<()<>>)[{(){}}(<>())]>{[<<>[]>{()()}]{(()[]){<><>}}}}<{([(){})){{[]}<{}{}
# Processing line: (<{<[<<{(<{({<{}()>{<>{}}}{[()[]]{<>[]}})<({{}}{<><>})[<(){}>[<><>]]>}>)}>>]><<({<[{([{{()<>}[[]{}
# > Incomplete line 15: 14 ['(', '<', '{', '<', '<', '(', '{', '<', '[', '{', '(', '[', '{', '[']
# > Incomplete line 15: 13 ['(', '<', '{', '<', '<', '(', '{', '<', '[', '{', '(', '[', '{']
# > Incomplete line 15: 12 ['(', '<', '{', '<', '<', '(', '{', '<', '[', '{', '(', '[']
# > Incomplete line 15: 11 ['(', '<', '{', '<', '<', '(', '{', '<', '[', '{', '(']
# > Incomplete line 15: 10 ['(', '<', '{', '<', '<', '(', '{', '<', '[', '{']
# > Incomplete line 15: 9 ['(', '<', '{', '<', '<', '(', '{', '<', '[']
# > Incomplete line 15: 8 ['(', '<', '{', '<', '<', '(', '{', '<']
# > Incomplete line 15: 7 ['(', '<', '{', '<', '<', '(', '{']
# > Incomplete line 15: 6 ['(', '<', '{', '<', '<', '(']
# > Incomplete line 15: 5 ['(', '<', '{', '<', '<']
# > Incomplete line 15: 4 ['(', '<', '{', '<']
# > Incomplete line 15: 3 ['(', '<', '{']
# > Incomplete line 15: 2 ['(', '<']
# > Incomplete line 15: 1 ['(']
# Processing line: [{{<{(({[<([[[()][<><>]][[<>[]]<<>()>]]<[{{}[]}({}<>)]([[][]]<<>{}})>)>]})(<([([(([][])[()<>]){[<>[]]({}
# Processing line: [[{[{{[[((<{<{<>()}([]<>)>([<>{}]<[]()>)})({[{<>[]}<{}<>>](<(){}>(<>{}))}({((){})({}<>)}<<<>
# Processing line: <{(<<<{[[(<(<[{}()]{[][]}>[{<>}[<>{}]])((<()()>[[]{}]))>([<([][]){[]<>}>([(){}]{(){}})]<({[
# > Incomplete line 18: 15 ['<', '{', '(', '<', '<', '<', '{', '[', '[', '(', '(', '<', '(', '{', '[']
# > Incomplete line 18: 14 ['<', '{', '(', '<', '<', '<', '{', '[', '[', '(', '(', '<', '(', '{']
# > Incomplete line 18: 13 ['<', '{', '(', '<', '<', '<', '{', '[', '[', '(', '(', '<', '(']
# > Incomplete line 18: 12 ['<', '{', '(', '<', '<', '<', '{', '[', '[', '(', '(', '<']
# > Incomplete line 18: 11 ['<', '{', '(', '<', '<', '<', '{', '[', '[', '(', '(']
# > Incomplete line 18: 10 ['<', '{', '(', '<', '<', '<', '{', '[', '[', '(']
# > Incomplete line 18: 9 ['<', '{', '(', '<', '<', '<', '{', '[', '[']
# > Incomplete line 18: 8 ['<', '{', '(', '<', '<', '<', '{', '[']
# > Incomplete line 18: 7 ['<', '{', '(', '<', '<', '<', '{']
# > Incomplete line 18: 6 ['<', '{', '(', '<', '<', '<']
# > Incomplete line 18: 5 ['<', '{', '(', '<', '<']
# > Incomplete line 18: 4 ['<', '{', '(', '<']
# > Incomplete line 18: 3 ['<', '{', '(']
# > Incomplete line 18: 2 ['<', '{']
# > Incomplete line 18: 1 ['<']
# Processing line: [(([([[{(([{[{<>{}}<{}<>>][[(){}]([]{})]}([<[]<>>{[][]}][[{}]{[]()}])})<<({({}{})<[]{}>}<{{}<>}<{}[]>>
# Processing line: <({<<<<({<[{[<{}()>](<<>{}>[[]<>])}]<[{(()<>)([]())}(({}<>){{}<>})]{({(){}}[{}[]]>({<><>}<{}{}>)}>><{<<(
# Processing line: [[<<<(<{([(<<{{}()}<{}()>>(([][])[[]{}])>{<{<>[]}><[<>{}]>})(([[<>{}]([]())]))]>}<<{<{(([]{}){()<>})<<{}<>>
# Processing line: <{<[{[<([(<<{{{}()}({}())}<((){})<[]{}>}>({<[]()><()<>>}[{()()}[<>]])>(([{<>()}<<>()>][([][])])(((()[]))<((
# Processing line: <{[<{{[<(<<{[([][])<{}[]>]<<[]<>>>}{({<>()}<[]<>>){{()()}{[]{}}}}>>[<<<({}[])>{[{}[]](()[])}>>
# > Incomplete line 23: 10 ['<', '{', '[', '<', '{', '{', '[', '<', '(', '[']
# > Incomplete line 23: 9 ['<', '{', '[', '<', '{', '{', '[', '<', '(']
# > Incomplete line 23: 8 ['<', '{', '[', '<', '{', '{', '[', '<']
# > Incomplete line 23: 7 ['<', '{', '[', '<', '{', '{', '[']
# > Incomplete line 23: 6 ['<', '{', '[', '<', '{', '{']
# > Incomplete line 23: 5 ['<', '{', '[', '<', '{']
# > Incomplete line 23: 4 ['<', '{', '[', '<']
# > Incomplete line 23: 3 ['<', '{', '[']
# > Incomplete line 23: 2 ['<', '{']
# > Incomplete line 23: 1 ['<']
# Processing line: (<(<[{{{[((({[{}{}]<<>()>}]{([<>[]](()[]))})[[{<<>[]>[{}()]}[[{}[]][{}[]]]][{(<><>)[<><>]}[<<><>>[
# Processing line: ([([<[<{<[<<[<[]{}>({}())][<{}[]>({})]>[({[]}{[]<>})<<{}[]>[{}{}]>]>[[{<{}()>[<><>]}{([]<>)([]())}]{(
# > Incomplete line 25: 13 ['(', '[', '(', '[', '<', '[', '<', '{', '<', '[', '[', '{', '(']
# > Incomplete line 25: 12 ['(', '[', '(', '[', '<', '[', '<', '{', '<', '[', '[', '{']
# > Incomplete line 25: 11 ['(', '[', '(', '[', '<', '[', '<', '{', '<', '[', '[']
# > Incomplete line 25: 10 ['(', '[', '(', '[', '<', '[', '<', '{', '<', '[']
# > Incomplete line 25: 9 ['(', '[', '(', '[', '<', '[', '<', '{', '<']
# > Incomplete line 25: 8 ['(', '[', '(', '[', '<', '[', '<', '{']
# > Incomplete line 25: 7 ['(', '[', '(', '[', '<', '[', '<']
# > Incomplete line 25: 6 ['(', '[', '(', '[', '<', '[']
# > Incomplete line 25: 5 ['(', '[', '(', '[', '<']
# > Incomplete line 25: 4 ['(', '[', '(', '[']
# > Incomplete line 25: 3 ['(', '[', '(']
# > Incomplete line 25: 2 ['(', '[']
# > Incomplete line 25: 1 ['(']
# Processing line: ({[((({(<[{[([{}<>](()<>))[(()())[()()]]]}]>){({(<<(()())[[]<>]>{{(){}}{<>}}>(<(<>())[(){}]>))<{{[<>()][(
# > Incomplete line 26: 15 ['(', '{', '[', '(', '(', '(', '{', '{', '(', '{', '<', '{', '{', '[', '(']
# > Incomplete line 26: 14 ['(', '{', '[', '(', '(', '(', '{', '{', '(', '{', '<', '{', '{', '[']
# > Incomplete line 26: 13 ['(', '{', '[', '(', '(', '(', '{', '{', '(', '{', '<', '{', '{']
# > Incomplete line 26: 12 ['(', '{', '[', '(', '(', '(', '{', '{', '(', '{', '<', '{']
# > Incomplete line 26: 11 ['(', '{', '[', '(', '(', '(', '{', '{', '(', '{', '<']
# > Incomplete line 26: 10 ['(', '{', '[', '(', '(', '(', '{', '{', '(', '{']
# > Incomplete line 26: 9 ['(', '{', '[', '(', '(', '(', '{', '{', '(']
# > Incomplete line 26: 8 ['(', '{', '[', '(', '(', '(', '{', '{']
# > Incomplete line 26: 7 ['(', '{', '[', '(', '(', '(', '{']
# > Incomplete line 26: 6 ['(', '{', '[', '(', '(', '(']
# > Incomplete line 26: 5 ['(', '{', '[', '(', '(']
# > Incomplete line 26: 4 ['(', '{', '[', '(']
# > Incomplete line 26: 3 ['(', '{', '[']
# > Incomplete line 26: 2 ['(', '{']
# > Incomplete line 26: 1 ['(']
# Processing line: {<{<{({<([({<(<><>){<><>}>(<[][]>{<>()})}<<([]()){<>()}><([][])[(){}]>>){(<<()()>}<{{}{}}({}{})>)((<{}{}>(
# Processing line: <{{(<([{<(([(<{}<>>[{}{}])([[][]]{[]<>})]({<()[]>})){<(([]<>)({}[]))><[({}<>)]([()<>](()()))>})>[<{(<<[](
# > Incomplete line 28: 15 ['<', '{', '{', '(', '<', '(', '[', '{', '[', '<', '{', '(', '<', '<', '(']
# > Incomplete line 28: 14 ['<', '{', '{', '(', '<', '(', '[', '{', '[', '<', '{', '(', '<', '<']
# > Incomplete line 28: 13 ['<', '{', '{', '(', '<', '(', '[', '{', '[', '<', '{', '(', '<']
# > Incomplete line 28: 12 ['<', '{', '{', '(', '<', '(', '[', '{', '[', '<', '{', '(']
# > Incomplete line 28: 11 ['<', '{', '{', '(', '<', '(', '[', '{', '[', '<', '{']
# > Incomplete line 28: 10 ['<', '{', '{', '(', '<', '(', '[', '{', '[', '<']
# > Incomplete line 28: 9 ['<', '{', '{', '(', '<', '(', '[', '{', '[']
# > Incomplete line 28: 8 ['<', '{', '{', '(', '<', '(', '[', '{']
# > Incomplete line 28: 7 ['<', '{', '{', '(', '<', '(', '[']
# > Incomplete line 28: 6 ['<', '{', '{', '(', '<', '(']
# > Incomplete line 28: 5 ['<', '{', '{', '(', '<']
# > Incomplete line 28: 4 ['<', '{', '{', '(']
# > Incomplete line 28: 3 ['<', '{', '{']
# > Incomplete line 28: 2 ['<', '{']
# > Incomplete line 28: 1 ['<']
# Processing line: <{<<(({{<{<{([<><>]({}[]))[<<>[]>(()<>)]}{[{()}][<[]>{{}()}]}>}<<[{{(){}}{()[]}}[<[]<>>{[]<>}]]([<{}{}>{<>[]
# > Incomplete line 29: 14 ['<', '{', '<', '<', '(', '(', '{', '{', '<', '<', '<', '(', '[', '{']
# > Incomplete line 29: 13 ['<', '{', '<', '<', '(', '(', '{', '{', '<', '<', '<', '(', '[']
# > Incomplete line 29: 12 ['<', '{', '<', '<', '(', '(', '{', '{', '<', '<', '<', '(']
# > Incomplete line 29: 11 ['<', '{', '<', '<', '(', '(', '{', '{', '<', '<', '<']
# > Incomplete line 29: 10 ['<', '{', '<', '<', '(', '(', '{', '{', '<', '<']
# > Incomplete line 29: 9 ['<', '{', '<', '<', '(', '(', '{', '{', '<']
# > Incomplete line 29: 8 ['<', '{', '<', '<', '(', '(', '{', '{']
# > Incomplete line 29: 7 ['<', '{', '<', '<', '(', '(', '{']
# > Incomplete line 29: 6 ['<', '{', '<', '<', '(', '(']
# > Incomplete line 29: 5 ['<', '{', '<', '<', '(']
# > Incomplete line 29: 4 ['<', '{', '<', '<']
# > Incomplete line 29: 3 ['<', '{', '<']
# > Incomplete line 29: 2 ['<', '{']
# > Incomplete line 29: 1 ['<']
# Processing line: <<<[[((<({<<(([][])<<>[]>)[[[]<>]<{}{}>]>({{()<>}}{<[]{}><()<>>})>}<(<<([]<>)<[]>>{[<><>]}>[[[()[]]<{}{}>]({[
# > Incomplete line 30: 15 ['<', '<', '<', '[', '[', '(', '(', '<', '(', '<', '(', '[', '(', '{', '[']
# > Incomplete line 30: 14 ['<', '<', '<', '[', '[', '(', '(', '<', '(', '<', '(', '[', '(', '{']
# > Incomplete line 30: 13 ['<', '<', '<', '[', '[', '(', '(', '<', '(', '<', '(', '[', '(']
# > Incomplete line 30: 12 ['<', '<', '<', '[', '[', '(', '(', '<', '(', '<', '(', '[']
# > Incomplete line 30: 11 ['<', '<', '<', '[', '[', '(', '(', '<', '(', '<', '(']
# > Incomplete line 30: 10 ['<', '<', '<', '[', '[', '(', '(', '<', '(', '<']
# > Incomplete line 30: 9 ['<', '<', '<', '[', '[', '(', '(', '<', '(']
# > Incomplete line 30: 8 ['<', '<', '<', '[', '[', '(', '(', '<']
# > Incomplete line 30: 7 ['<', '<', '<', '[', '[', '(', '(']
# > Incomplete line 30: 6 ['<', '<', '<', '[', '[', '(']
# > Incomplete line 30: 5 ['<', '<', '<', '[', '[']
# > Incomplete line 30: 4 ['<', '<', '<', '[']
# > Incomplete line 30: 3 ['<', '<', '<']
# > Incomplete line 30: 2 ['<', '<']
# > Incomplete line 30: 1 ['<']
# Processing line: [[({{((({(<(<([]{})([]{})>({{}[]}([]()]))>({<{(){}}[[][]]>(([]{})[<><>])}([{[][]}<<>()>])))[(<<[[]<>][{}<>]>
# Processing line: ({[{{(({{[<(<[<>{}]((){})><[<><>]([]())>)<{({}<>)<{}()>}{{(){}}<[]{}>}>>[{{<<>{}>{{}}}<[{}[]][{
# > Incomplete line 32: 15 ['(', '{', '[', '{', '{', '(', '(', '{', '{', '[', '[', '{', '<', '[', '{']
# > Incomplete line 32: 14 ['(', '{', '[', '{', '{', '(', '(', '{', '{', '[', '[', '{', '<', '[']
# > Incomplete line 32: 13 ['(', '{', '[', '{', '{', '(', '(', '{', '{', '[', '[', '{', '<']
# > Incomplete line 32: 12 ['(', '{', '[', '{', '{', '(', '(', '{', '{', '[', '[', '{']
# > Incomplete line 32: 11 ['(', '{', '[', '{', '{', '(', '(', '{', '{', '[', '[']
# > Incomplete line 32: 10 ['(', '{', '[', '{', '{', '(', '(', '{', '{', '[']
# > Incomplete line 32: 9 ['(', '{', '[', '{', '{', '(', '(', '{', '{']
# > Incomplete line 32: 8 ['(', '{', '[', '{', '{', '(', '(', '{']
# > Incomplete line 32: 7 ['(', '{', '[', '{', '{', '(', '(']
# > Incomplete line 32: 6 ['(', '{', '[', '{', '{', '(']
# > Incomplete line 32: 5 ['(', '{', '[', '{', '{']
# > Incomplete line 32: 4 ['(', '{', '[', '{']
# > Incomplete line 32: 3 ['(', '{', '[']
# > Incomplete line 32: 2 ['(', '{']
# > Incomplete line 32: 1 ['(']
# Processing line: {[{{(<(([([{[[(){}](()<>)]<[[][]]([][])>}]{{(((){})([]<>))(([]<>)[()<>])}{[<{}[]>]<[<><>](<>())>}
# > Incomplete line 33: 11 ['{', '[', '{', '{', '(', '<', '(', '(', '[', '(', '{']
# > Incomplete line 33: 10 ['{', '[', '{', '{', '(', '<', '(', '(', '[', '(']
# > Incomplete line 33: 9 ['{', '[', '{', '{', '(', '<', '(', '(', '[']
# > Incomplete line 33: 8 ['{', '[', '{', '{', '(', '<', '(', '(']
# > Incomplete line 33: 7 ['{', '[', '{', '{', '(', '<', '(']
# > Incomplete line 33: 6 ['{', '[', '{', '{', '(', '<']
# > Incomplete line 33: 5 ['{', '[', '{', '{', '(']
# > Incomplete line 33: 4 ['{', '[', '{', '{']
# > Incomplete line 33: 3 ['{', '[', '{']
# > Incomplete line 33: 2 ['{', '[']
# > Incomplete line 33: 1 ['{']
# Processing line: ({({{[<<{((((<[]{}>{<><>})))({<<<>{}>({}())>}<<<[]()>{{}()}>[<{}[]>[<><>]]>))[(<(({}[])<<>()>>({{}<>}<[]<
# Processing line: {{[{<((<{<(({[()()]{{}[]}}{([]()){<>{}}>)<[[[][]]({}[])]>)<({(()<>)[<>]})<[[()<>]]<[()()]<[]<>>>>>>{[((
# Processing line: [(<<<<<[<(([[{()()}[()<>]]]{(<{}{}>{{}[]})<<[]()>([][])>}){[{<[]()>{{}<>}}{[[][]][{}]>]})>]<{{(<<[[]{}
# Processing line: (({[<[<([[<({[{}<>]}[(()()){<>{}}])<(<<>()>)[(()<>){{}{}}]>>]{<(([()()][[]<>]){{[]{}}([][])})>}][[
# > Incomplete line 37: 10 ['(', '(', '{', '[', '<', '[', '<', '(', '[', '[']
# > Incomplete line 37: 9 ['(', '(', '{', '[', '<', '[', '<', '(', '[']
# > Incomplete line 37: 8 ['(', '(', '{', '[', '<', '[', '<', '(']
# > Incomplete line 37: 7 ['(', '(', '{', '[', '<', '[', '<']
# > Incomplete line 37: 6 ['(', '(', '{', '[', '<', '[']
# > Incomplete line 37: 5 ['(', '(', '{', '[', '<']
# > Incomplete line 37: 4 ['(', '(', '{', '[']
# > Incomplete line 37: 3 ['(', '(', '{']
# > Incomplete line 37: 2 ['(', '(']
# > Incomplete line 37: 1 ['(']
# Processing line: [<((<{([(({{{{{}}{[]()}}<{()<>}{(){}}>}}[(<<{}{}>><[<><>]{[]<>}>)<{<<><>>{()<>}}<[()<>]{[]{}}>>]))]{(({{
# > Incomplete line 38: 12 ['[', '<', '(', '(', '<', '{', '(', '{', '(', '(', '{', '{']
# > Incomplete line 38: 11 ['[', '<', '(', '(', '<', '{', '(', '{', '(', '(', '{']
# > Incomplete line 38: 10 ['[', '<', '(', '(', '<', '{', '(', '{', '(', '(']
# > Incomplete line 38: 9 ['[', '<', '(', '(', '<', '{', '(', '{', '(']
# > Incomplete line 38: 8 ['[', '<', '(', '(', '<', '{', '(', '{']
# > Incomplete line 38: 7 ['[', '<', '(', '(', '<', '{', '(']
# > Incomplete line 38: 6 ['[', '<', '(', '(', '<', '{']
# > Incomplete line 38: 5 ['[', '<', '(', '(', '<']
# > Incomplete line 38: 4 ['[', '<', '(', '(']
# > Incomplete line 38: 3 ['[', '<', '(']
# > Incomplete line 38: 2 ['[', '<']
# > Incomplete line 38: 1 ['[']
# Processing line: {[[<([<[{{(<[([]<>)([]<>)][[<>{}]]>){({{()<>}<[]{}>}<{<>{}}(<><>)>)>}{<<{((){}){<>{}}}<[<><>]([]())>
# Processing line: {[{([<<{<((<(<(){}>([]()))<{()<>}<{}()>>><<[{}()]{()()}>>)[({<{}{}>{{}<>}}<[[]()](<>())>)(([()<>][[]<
# > Incomplete line 40: 15 ['{', '[', '{', '(', '[', '<', '<', '{', '<', '(', '[', '(', '(', '[', '<']
# > Incomplete line 40: 14 ['{', '[', '{', '(', '[', '<', '<', '{', '<', '(', '[', '(', '(', '[']
# > Incomplete line 40: 13 ['{', '[', '{', '(', '[', '<', '<', '{', '<', '(', '[', '(', '(']
# > Incomplete line 40: 12 ['{', '[', '{', '(', '[', '<', '<', '{', '<', '(', '[', '(']
# > Incomplete line 40: 11 ['{', '[', '{', '(', '[', '<', '<', '{', '<', '(', '[']
# > Incomplete line 40: 10 ['{', '[', '{', '(', '[', '<', '<', '{', '<', '(']
# > Incomplete line 40: 9 ['{', '[', '{', '(', '[', '<', '<', '{', '<']
# > Incomplete line 40: 8 ['{', '[', '{', '(', '[', '<', '<', '{']
# > Incomplete line 40: 7 ['{', '[', '{', '(', '[', '<', '<']
# > Incomplete line 40: 6 ['{', '[', '{', '(', '[', '<']
# > Incomplete line 40: 5 ['{', '[', '{', '(', '[']
# > Incomplete line 40: 4 ['{', '[', '{', '(']
# > Incomplete line 40: 3 ['{', '[', '{']
# > Incomplete line 40: 2 ['{', '[']
# > Incomplete line 40: 1 ['{']
# Processing line: <<[<{[<<[<<(<<()>{()<>}>{[[]<>]<<>[]>})>{<<{<>()}(()<>)><(()<>)<()<>>>>{[([]())([]<>)][[{}()]
# > Incomplete line 41: 13 ['<', '<', '[', '<', '{', '[', '<', '<', '[', '<', '{', '{', '[']
# > Incomplete line 41: 12 ['<', '<', '[', '<', '{', '[', '<', '<', '[', '<', '{', '{']
# > Incomplete line 41: 11 ['<', '<', '[', '<', '{', '[', '<', '<', '[', '<', '{']
# > Incomplete line 41: 10 ['<', '<', '[', '<', '{', '[', '<', '<', '[', '<']
# > Incomplete line 41: 9 ['<', '<', '[', '<', '{', '[', '<', '<', '[']
# > Incomplete line 41: 8 ['<', '<', '[', '<', '{', '[', '<', '<']
# > Incomplete line 41: 7 ['<', '<', '[', '<', '{', '[', '<']
# > Incomplete line 41: 6 ['<', '<', '[', '<', '{', '[']
# > Incomplete line 41: 5 ['<', '<', '[', '<', '{']
# > Incomplete line 41: 4 ['<', '<', '[', '<']
# > Incomplete line 41: 3 ['<', '<', '[']
# > Incomplete line 41: 2 ['<', '<']
# > Incomplete line 41: 1 ['<']
# Processing line: ({<{<[<{{([[[{[]()}[[]<>]]][<<{}{}><()()>>[({}[])(<>{})]]>)[{(((()<>)([][]))){<<[]>(()())>}}((
# Processing line: [<{<<({(((<<<[()<>][()<>]>>[(<[][]>[[]<>])]>){{[((()<>)<{}<>>)[[<>[]]((){})]]][([{{}()}[[]]](<<>
# Processing line: <{{{[<(([([[<({}<>)[<><>]>([[][]](()))]]]])(<{([<[()<>][<>[]]>{[<>{}]([]<>)}](<{(){}}<()()>><<()()>[[]{}]
# Processing line: {{[({([{{({<((()<>){()[]})>[[{<>[]}]{[{}<>]{<>()}}]}<<<<[]>[{}[]]>{({}<>)[()<>]}>(<[<>()]{<>[]}>)>)
# > Incomplete line 45: 9 ['{', '{', '[', '(', '{', '(', '[', '{', '{']
# > Incomplete line 45: 8 ['{', '{', '[', '(', '{', '(', '[', '{']
# > Incomplete line 45: 7 ['{', '{', '[', '(', '{', '(', '[']
# > Incomplete line 45: 6 ['{', '{', '[', '(', '{', '(']
# > Incomplete line 45: 5 ['{', '{', '[', '(', '{']
# > Incomplete line 45: 4 ['{', '{', '[', '(']
# > Incomplete line 45: 3 ['{', '{', '[']
# > Incomplete line 45: 2 ['{', '{']
# > Incomplete line 45: 1 ['{']
# Processing line: <[<(([{{(<([(([]<>)([]()))<(<>{}){{}<>}>][[<[]{}>{<>{}}]{<<>{}>}])([[<{}{}>(<>{})]<[[]()>>]<([(){}]([]()))
# Processing line: <[{(([<{{<{{<[()()]><(<>())>}}<{[<()()>]<[()[]][()[]]>}<([()[]]({}<>)){{<>[]}[<>()]}>>}}[(<<[([]()){{}
# Processing line: <{{[<<[[<([<<[()[]][()<>]>(<<>[]>[()<>])>])([{{[[]{}]<{}[]>}({<>[]})}]<<[(<>[])([][])][<<>()>]>>)><[
# > Incomplete line 48: 10 ['<', '{', '{', '[', '<', '<', '[', '[', '<', '[']
# > Incomplete line 48: 9 ['<', '{', '{', '[', '<', '<', '[', '[', '<']
# > Incomplete line 48: 8 ['<', '{', '{', '[', '<', '<', '[', '[']
# > Incomplete line 48: 7 ['<', '{', '{', '[', '<', '<', '[']
# > Incomplete line 48: 6 ['<', '{', '{', '[', '<', '<']
# > Incomplete line 48: 5 ['<', '{', '{', '[', '<']
# > Incomplete line 48: 4 ['<', '{', '{', '[']
# > Incomplete line 48: 3 ['<', '{', '{']
# > Incomplete line 48: 2 ['<', '{']
# > Incomplete line 48: 1 ['<']
# Processing line: <<{{[({{{{<[<{[]<>}({}{})>{(<>())(<>[])}]({([][])(()<>)})>(<{([][])<[][]>}([[]]<()()>]>{{[()
# Processing line: [[{[{([[[{[{[([]<>){<>{}}](<<>()>)}{[<[]{}>[{}[]]]}]}[([([<>()])]<<[<>][[]<>]>{({})[<>{}]}>]<({
# Processing line: (([[{(<{{<([[(<>){<>()}]<[[]{}]<()<>>>]{({{}[]}<<>{}>)<([]{})[(){}]>})>({<(({}[])<()<>>)>}((<<()()>
# > Incomplete line 51: 13 ['(', '(', '[', '[', '{', '(', '<', '{', '{', '(', '(', '(', '<']
# > Incomplete line 51: 12 ['(', '(', '[', '[', '{', '(', '<', '{', '{', '(', '(', '(']
# > Incomplete line 51: 11 ['(', '(', '[', '[', '{', '(', '<', '{', '{', '(', '(']
# > Incomplete line 51: 10 ['(', '(', '[', '[', '{', '(', '<', '{', '{', '(']
# > Incomplete line 51: 9 ['(', '(', '[', '[', '{', '(', '<', '{', '{']
# > Incomplete line 51: 8 ['(', '(', '[', '[', '{', '(', '<', '{']
# > Incomplete line 51: 7 ['(', '(', '[', '[', '{', '(', '<']
# > Incomplete line 51: 6 ['(', '(', '[', '[', '{', '(']
# > Incomplete line 51: 5 ['(', '(', '[', '[', '{']
# > Incomplete line 51: 4 ['(', '(', '[', '[']
# > Incomplete line 51: 3 ['(', '(', '[']
# > Incomplete line 51: 2 ['(', '(']
# > Incomplete line 51: 1 ['(']
# Processing line: <{(<<(<[<{{<<{()[]}{{}()}><<<>][[]{}]>>([([]<>)<<>{}>])}[{[<{}[]>]<<{}[]>{<>[]}>}]}[{{{<<><>>{()<>}}}
# Processing line: (({(<<((<{<(<<()>([]())>){({[][]}<[]()>){<<>{}>([])}}>{(<([][])<<>()>>)}}{[<((<><>)([]<>)){(()[])}>{<<[
# > Incomplete line 53: 15 ['(', '(', '{', '(', '<', '<', '(', '(', '<', '{', '[', '{', '<', '<', '[']
# > Incomplete line 53: 14 ['(', '(', '{', '(', '<', '<', '(', '(', '<', '{', '[', '{', '<', '<']
# > Incomplete line 53: 13 ['(', '(', '{', '(', '<', '<', '(', '(', '<', '{', '[', '{', '<']
# > Incomplete line 53: 12 ['(', '(', '{', '(', '<', '<', '(', '(', '<', '{', '[', '{']
# > Incomplete line 53: 11 ['(', '(', '{', '(', '<', '<', '(', '(', '<', '{', '[']
# > Incomplete line 53: 10 ['(', '(', '{', '(', '<', '<', '(', '(', '<', '{']
# > Incomplete line 53: 9 ['(', '(', '{', '(', '<', '<', '(', '(', '<']
# > Incomplete line 53: 8 ['(', '(', '{', '(', '<', '<', '(', '(']
# > Incomplete line 53: 7 ['(', '(', '{', '(', '<', '<', '(']
# > Incomplete line 53: 6 ['(', '(', '{', '(', '<', '<']
# > Incomplete line 53: 5 ['(', '(', '{', '(', '<']
# > Incomplete line 53: 4 ['(', '(', '{', '(']
# > Incomplete line 53: 3 ['(', '(', '{']
# > Incomplete line 53: 2 ['(', '(']
# > Incomplete line 53: 1 ['(']
# Processing line: {[{[([((((([([[]{}][()[]])<(()())[<>[]]>]))[([[<<>()>{{}<>}](({}<>))][[({}[])]])]))[{({[[<<><>>][(()<>)<<>()
# > Incomplete line 54: 14 ['{', '[', '{', '[', '(', '[', '(', '[', '{', '(', '{', '[', '[', '<']
# > Incomplete line 54: 13 ['{', '[', '{', '[', '(', '[', '(', '[', '{', '(', '{', '[', '[']
# > Incomplete line 54: 12 ['{', '[', '{', '[', '(', '[', '(', '[', '{', '(', '{', '[']
# > Incomplete line 54: 11 ['{', '[', '{', '[', '(', '[', '(', '[', '{', '(', '{']
# > Incomplete line 54: 10 ['{', '[', '{', '[', '(', '[', '(', '[', '{', '(']
# > Incomplete line 54: 9 ['{', '[', '{', '[', '(', '[', '(', '[', '{']
# > Incomplete line 54: 8 ['{', '[', '{', '[', '(', '[', '(', '[']
# > Incomplete line 54: 7 ['{', '[', '{', '[', '(', '[', '(']
# > Incomplete line 54: 6 ['{', '[', '{', '[', '(', '[']
# > Incomplete line 54: 5 ['{', '[', '{', '[', '(']
# > Incomplete line 54: 4 ['{', '[', '{', '[']
# > Incomplete line 54: 3 ['{', '[', '{']
# > Incomplete line 54: 2 ['{', '[']
# > Incomplete line 54: 1 ['{']
# Processing line: <<(<([([({(({{{}()}(())}[(<>[])({}<>)])([([][]){[]<>}]{{[][]}[(){}]})){(<<<>()>[[][]]><<[][]>
# > Incomplete line 55: 13 ['<', '<', '(', '<', '(', '[', '(', '[', '(', '{', '{', '(', '<']
# > Incomplete line 55: 12 ['<', '<', '(', '<', '(', '[', '(', '[', '(', '{', '{', '(']
# > Incomplete line 55: 11 ['<', '<', '(', '<', '(', '[', '(', '[', '(', '{', '{']
# > Incomplete line 55: 10 ['<', '<', '(', '<', '(', '[', '(', '[', '(', '{']
# > Incomplete line 55: 9 ['<', '<', '(', '<', '(', '[', '(', '[', '(']
# > Incomplete line 55: 8 ['<', '<', '(', '<', '(', '[', '(', '[']
# > Incomplete line 55: 7 ['<', '<', '(', '<', '(', '[', '(']
# > Incomplete line 55: 6 ['<', '<', '(', '<', '(', '[']
# > Incomplete line 55: 5 ['<', '<', '(', '<', '(']
# > Incomplete line 55: 4 ['<', '<', '(', '<']
# > Incomplete line 55: 3 ['<', '<', '(']
# > Incomplete line 55: 2 ['<', '<']
# > Incomplete line 55: 1 ['<']
# Processing line: [<<{{{({[<{[<[[]{}]<{}<>>>[[[]<>][<>{}]]]<{{<>{})({}[])}>}([{<<>()><{}()>}]([{{}[]}{[]<>}][(<>())[[]{}]]))
# Processing line: [([({{[<{<<((([]{})({}<>))[<<>[]><[]{}>])><<<((){})[()()]>>[{<{}{}><<>[]>}<<<>><<>{}>>]>>[{(
# > Incomplete line 57: 12 ['[', '(', '[', '(', '{', '{', '[', '<', '{', '[', '{', '(']
# > Incomplete line 57: 11 ['[', '(', '[', '(', '{', '{', '[', '<', '{', '[', '{']
# > Incomplete line 57: 10 ['[', '(', '[', '(', '{', '{', '[', '<', '{', '[']
# > Incomplete line 57: 9 ['[', '(', '[', '(', '{', '{', '[', '<', '{']
# > Incomplete line 57: 8 ['[', '(', '[', '(', '{', '{', '[', '<']
# > Incomplete line 57: 7 ['[', '(', '[', '(', '{', '{', '[']
# > Incomplete line 57: 6 ['[', '(', '[', '(', '{', '{']
# > Incomplete line 57: 5 ['[', '(', '[', '(', '{']
# > Incomplete line 57: 4 ['[', '(', '[', '(']
# > Incomplete line 57: 3 ['[', '(', '[']
# > Incomplete line 57: 2 ['[', '(']
# > Incomplete line 57: 1 ['[']
# Processing line: [({{(<{<([({[<<><>>({}[])]({<>()}<{}[]>]})])>}><([<<<[{<<><>>[[][]]}<[{}[]]<<><>>>]([{()<>
# Processing line: <{<<[((<{<{<<{[]<>}{[][]}>{[{}[]][<>{}]}>[{{[]<>}<<>[]>}<[<>()][()<>]>]}(<{(<>[])(<>())}>{{(()[]
# > Incomplete line 59: 14 ['<', '{', '<', '<', '[', '(', '(', '<', '{', '<', '(', '{', '{', '(']
# > Incomplete line 59: 13 ['<', '{', '<', '<', '[', '(', '(', '<', '{', '<', '(', '{', '{']
# > Incomplete line 59: 12 ['<', '{', '<', '<', '[', '(', '(', '<', '{', '<', '(', '{']
# > Incomplete line 59: 11 ['<', '{', '<', '<', '[', '(', '(', '<', '{', '<', '(']
# > Incomplete line 59: 10 ['<', '{', '<', '<', '[', '(', '(', '<', '{', '<']
# > Incomplete line 59: 9 ['<', '{', '<', '<', '[', '(', '(', '<', '{']
# > Incomplete line 59: 8 ['<', '{', '<', '<', '[', '(', '(', '<']
# > Incomplete line 59: 7 ['<', '{', '<', '<', '[', '(', '(']
# > Incomplete line 59: 6 ['<', '{', '<', '<', '[', '(']
# > Incomplete line 59: 5 ['<', '{', '<', '<', '[']
# > Incomplete line 59: 4 ['<', '{', '<', '<']
# > Incomplete line 59: 3 ['<', '{', '<']
# > Incomplete line 59: 2 ['<', '{']
# > Incomplete line 59: 1 ['<']
# Processing line: [[[{({<(({[{([<>{}]{<>})(([]{})(()[]))}]}<[((<<>{}}[<><>])<<{}[]>>)(<<(){}>(()<>)>[<()()>([]<>)])]({([{}[]]
# Processing line: {{<[<[({[([[{[{}{}][[]()]}{(()())}]{[<()()>{{}<>}]({[]<>}[()()])}])]{[<{[<()[]>]}({[<>{}][(){}]}[<[]<>>[()[]
# > Incomplete line 61: 14 ['{', '{', '<', '[', '<', '[', '(', '{', '{', '[', '<', '(', '[', '[']
# > Incomplete line 61: 13 ['{', '{', '<', '[', '<', '[', '(', '{', '{', '[', '<', '(', '[']
# > Incomplete line 61: 12 ['{', '{', '<', '[', '<', '[', '(', '{', '{', '[', '<', '(']
# > Incomplete line 61: 11 ['{', '{', '<', '[', '<', '[', '(', '{', '{', '[', '<']
# > Incomplete line 61: 10 ['{', '{', '<', '[', '<', '[', '(', '{', '{', '[']
# > Incomplete line 61: 9 ['{', '{', '<', '[', '<', '[', '(', '{', '{']
# > Incomplete line 61: 8 ['{', '{', '<', '[', '<', '[', '(', '{']
# > Incomplete line 61: 7 ['{', '{', '<', '[', '<', '[', '(']
# > Incomplete line 61: 6 ['{', '{', '<', '[', '<', '[']
# > Incomplete line 61: 5 ['{', '{', '<', '[', '<']
# > Incomplete line 61: 4 ['{', '{', '<', '[']
# > Incomplete line 61: 3 ['{', '{', '<']
# > Incomplete line 61: 2 ['{', '{']
# > Incomplete line 61: 1 ['{']
# Processing line: {[{{{([(<([(<{()}[{}()]>{{<>{}}{(){}}})[<<<>{}><<><>>>]])<([(<{}[]>)][(<()[]}[()<>])[(()())<{}[]>]])[(
# Processing line: <({([{<<<<{[([<>{}]<{}{}>)(<[]<>>[()<>])]}>><[{[<[[]{}]{(){}}>[<()[]][<>]]](<[[]()]([]{})>)}({((<><>))<{<><>}
# Processing line: [({<[{<<(([<({[]<>}<()()>)[{<>()}]>>{[[<<><>>{[][]}]([{}()](<>[]))]}))>>}]({(<{[(<<(()[])[{}<>]>
# Processing line: <([<<(({<{[[[{{}<>}([])]<{<><>}>]<<({}<>)<<><>>><<[]<>]<{}[]>>>]}{[{<{()}{()}>(<[]{}>{<>[]})}[(<<><>>{<>()})[
# Processing line: ({<{[(<<[<{([{<>{}}{<>()}]{{[][]}[[]<>]})}{({(<>())(())}<{()()}<()()>>){<({}{})<{}{}}>[({}<>
# Processing line: {{<<<[({({[{<({}())({}())>}{<{{}[]}[[]()]><(()<>)(<><>)>})})})<<<{{(<{()<>}{(){}}><{()()}([]<>)>)([(
# Processing line: {{[{[[[({<{{[(<>)[()[]]]}<<{<>[]}[<>[]]><[<>]<{}>>>}({[{[][]}([]())]}[[{{}{}}[()[]]]<[(){}]>])
# > Incomplete line 68: 10 ['{', '{', '[', '{', '[', '[', '[', '(', '{', '<']
# > Incomplete line 68: 9 ['{', '{', '[', '{', '[', '[', '[', '(', '{']
# > Incomplete line 68: 8 ['{', '{', '[', '{', '[', '[', '[', '(']
# > Incomplete line 68: 7 ['{', '{', '[', '{', '[', '[', '[']
# > Incomplete line 68: 6 ['{', '{', '[', '{', '[', '[']
# > Incomplete line 68: 5 ['{', '{', '[', '{', '[']
# > Incomplete line 68: 4 ['{', '{', '[', '{']
# > Incomplete line 68: 3 ['{', '{', '[']
# > Incomplete line 68: 2 ['{', '{']
# > Incomplete line 68: 1 ['{']
# Processing line: <{[([{((<[[<<<<><>><{}()>>[<{}()><<>[]>]>[<<{}()>{{}<>}><<{}<>>{[][]}>]]<[{({}[])}{[{}<>][<>
# > Incomplete line 69: 14 ['<', '{', '[', '(', '[', '{', '(', '(', '<', '[', '<', '[', '{', '[']
# > Incomplete line 69: 13 ['<', '{', '[', '(', '[', '{', '(', '(', '<', '[', '<', '[', '{']
# > Incomplete line 69: 12 ['<', '{', '[', '(', '[', '{', '(', '(', '<', '[', '<', '[']
# > Incomplete line 69: 11 ['<', '{', '[', '(', '[', '{', '(', '(', '<', '[', '<']
# > Incomplete line 69: 10 ['<', '{', '[', '(', '[', '{', '(', '(', '<', '[']
# > Incomplete line 69: 9 ['<', '{', '[', '(', '[', '{', '(', '(', '<']
# > Incomplete line 69: 8 ['<', '{', '[', '(', '[', '{', '(', '(']
# > Incomplete line 69: 7 ['<', '{', '[', '(', '[', '{', '(']
# > Incomplete line 69: 6 ['<', '{', '[', '(', '[', '{']
# > Incomplete line 69: 5 ['<', '{', '[', '(', '[']
# > Incomplete line 69: 4 ['<', '{', '[', '(']
# > Incomplete line 69: 3 ['<', '{', '[']
# > Incomplete line 69: 2 ['<', '{']
# > Incomplete line 69: 1 ['<']
# Processing line: [{<(([<{{{([{{<>{}}{(){}}}<[{}()]<<>()>)][{[{}{}]({}<>)}{(<>[])<()[]>}])<<[{{}[]}[[][]]]{[{}<>]<
# Processing line: ({{[[[{<([({[<()<>><{}[]>][([]{})({}())]}<[<[]{}>]{{[]{}}({}{})}>)<{[[[]()]<[]{}>][[<>[]]{[][]}]}([{[][]}<[]
# > Incomplete line 71: 14 ['(', '{', '{', '[', '[', '[', '{', '<', '(', '[', '<', '(', '[', '<']
# > Incomplete line 71: 13 ['(', '{', '{', '[', '[', '[', '{', '<', '(', '[', '<', '(', '[']
# > Incomplete line 71: 12 ['(', '{', '{', '[', '[', '[', '{', '<', '(', '[', '<', '(']
# > Incomplete line 71: 11 ['(', '{', '{', '[', '[', '[', '{', '<', '(', '[', '<']
# > Incomplete line 71: 10 ['(', '{', '{', '[', '[', '[', '{', '<', '(', '[']
# > Incomplete line 71: 9 ['(', '{', '{', '[', '[', '[', '{', '<', '(']
# > Incomplete line 71: 8 ['(', '{', '{', '[', '[', '[', '{', '<']
# > Incomplete line 71: 7 ['(', '{', '{', '[', '[', '[', '{']
# > Incomplete line 71: 6 ['(', '{', '{', '[', '[', '[']
# > Incomplete line 71: 5 ['(', '{', '{', '[', '[']
# > Incomplete line 71: 4 ['(', '{', '{', '[']
# > Incomplete line 71: 3 ['(', '{', '{']
# > Incomplete line 71: 2 ['(', '{']
# > Incomplete line 71: 1 ['(']
# Processing line: <((({{{[{(<{<[()[]]<{}[]>>[{(){}}({}[])]}<<([])<(){}>>(([]<>)[<>[]])>>)}<([({(()<>)<()<>>}{<[][]>[[][
# > Incomplete line 72: 15 ['<', '(', '(', '(', '{', '{', '{', '[', '<', '(', '[', '(', '{', '[', '[']
# > Incomplete line 72: 14 ['<', '(', '(', '(', '{', '{', '{', '[', '<', '(', '[', '(', '{', '[']
# > Incomplete line 72: 13 ['<', '(', '(', '(', '{', '{', '{', '[', '<', '(', '[', '(', '{']
# > Incomplete line 72: 12 ['<', '(', '(', '(', '{', '{', '{', '[', '<', '(', '[', '(']
# > Incomplete line 72: 11 ['<', '(', '(', '(', '{', '{', '{', '[', '<', '(', '[']
# > Incomplete line 72: 10 ['<', '(', '(', '(', '{', '{', '{', '[', '<', '(']
# > Incomplete line 72: 9 ['<', '(', '(', '(', '{', '{', '{', '[', '<']
# > Incomplete line 72: 8 ['<', '(', '(', '(', '{', '{', '{', '[']
# > Incomplete line 72: 7 ['<', '(', '(', '(', '{', '{', '{']
# > Incomplete line 72: 6 ['<', '(', '(', '(', '{', '{']
# > Incomplete line 72: 5 ['<', '(', '(', '(', '{']
# > Incomplete line 72: 4 ['<', '(', '(', '(']
# > Incomplete line 72: 3 ['<', '(', '(']
# > Incomplete line 72: 2 ['<', '(']
# > Incomplete line 72: 1 ['<']
# Processing line: [<({<[{[[{{(<[<>{}]({}())>({{}{}}{[]()})){[(<>()){()()}]{([][])[<>{}]}}}([<[[]()]([])>([[]()]<<><>>)]([<<>()>
# > Incomplete line 73: 13 ['[', '<', '(', '{', '<', '[', '{', '[', '[', '{', '(', '(', '[']
# > Incomplete line 73: 12 ['[', '<', '(', '{', '<', '[', '{', '[', '[', '{', '(', '(']
# > Incomplete line 73: 11 ['[', '<', '(', '{', '<', '[', '{', '[', '[', '{', '(']
# > Incomplete line 73: 10 ['[', '<', '(', '{', '<', '[', '{', '[', '[', '{']
# > Incomplete line 73: 9 ['[', '<', '(', '{', '<', '[', '{', '[', '[']
# > Incomplete line 73: 8 ['[', '<', '(', '{', '<', '[', '{', '[']
# > Incomplete line 73: 7 ['[', '<', '(', '{', '<', '[', '{']
# > Incomplete line 73: 6 ['[', '<', '(', '{', '<', '[']
# > Incomplete line 73: 5 ['[', '<', '(', '{', '<']
# > Incomplete line 73: 4 ['[', '<', '(', '{']
# > Incomplete line 73: 3 ['[', '<', '(']
# > Incomplete line 73: 2 ['[', '<']
# > Incomplete line 73: 1 ['[']
# Processing line: [<{[(<(<<({<{<{}()>[<>{}]}{[{}{}]{<>[]}}>{[{<><>}<[]{}>](({}<>)([]{}))}}([{<<>{})({}<>)}<{{}<>}{{}{}}>])){<[
# Processing line: [{<{{{{{{{<<({[][]}([]<>))[<()[]><<>[]>]><<(<><>)[{}[]]>((()[]))>>{{({<>[]}<<>()>)[[<>()]<<>{}>]}}}[<(
# > Incomplete line 75: 12 ['[', '{', '<', '{', '{', '{', '{', '{', '{', '[', '<', '(']
# > Incomplete line 75: 11 ['[', '{', '<', '{', '{', '{', '{', '{', '{', '[', '<']
# > Incomplete line 75: 10 ['[', '{', '<', '{', '{', '{', '{', '{', '{', '[']
# > Incomplete line 75: 9 ['[', '{', '<', '{', '{', '{', '{', '{', '{']
# > Incomplete line 75: 8 ['[', '{', '<', '{', '{', '{', '{', '{']
# > Incomplete line 75: 7 ['[', '{', '<', '{', '{', '{', '{']
# > Incomplete line 75: 6 ['[', '{', '<', '{', '{', '{']
# > Incomplete line 75: 5 ['[', '{', '<', '{', '{']
# > Incomplete line 75: 4 ['[', '{', '<', '{']
# > Incomplete line 75: 3 ['[', '{', '<']
# > Incomplete line 75: 2 ['[', '{']
# > Incomplete line 75: 1 ['[']
# Processing line: <(<[((<{[[[<[[<><>]([]())]{{()[]}([][])}>]](([([{}]{{}()}){[<><>]<[]<>>}]<((<>{}){{}<>})<{
# > Incomplete line 76: 14 ['<', '(', '<', '[', '(', '(', '<', '{', '[', '(', '(', '<', '<', '{']
# > Incomplete line 76: 13 ['<', '(', '<', '[', '(', '(', '<', '{', '[', '(', '(', '<', '<']
# > Incomplete line 76: 12 ['<', '(', '<', '[', '(', '(', '<', '{', '[', '(', '(', '<']
# > Incomplete line 76: 11 ['<', '(', '<', '[', '(', '(', '<', '{', '[', '(', '(']
# > Incomplete line 76: 10 ['<', '(', '<', '[', '(', '(', '<', '{', '[', '(']
# > Incomplete line 76: 9 ['<', '(', '<', '[', '(', '(', '<', '{', '[']
# > Incomplete line 76: 8 ['<', '(', '<', '[', '(', '(', '<', '{']
# > Incomplete line 76: 7 ['<', '(', '<', '[', '(', '(', '<']
# > Incomplete line 76: 6 ['<', '(', '<', '[', '(', '(']
# > Incomplete line 76: 5 ['<', '(', '<', '[', '(']
# > Incomplete line 76: 4 ['<', '(', '<', '[']
# > Incomplete line 76: 3 ['<', '(', '<']
# > Incomplete line 76: 2 ['<', '(']
# > Incomplete line 76: 1 ['<']
# Processing line: ([[(((((<<{({<{}[]>((){})}(<{}<>>[()[]])){<<{}()>(<>())>[({}[])<<>()>]}}>(<(<(()[])[[]()]>[<(
# > Incomplete line 77: 15 ['(', '[', '[', '(', '(', '(', '(', '(', '<', '(', '<', '(', '[', '<', '(']
# > Incomplete line 77: 14 ['(', '[', '[', '(', '(', '(', '(', '(', '<', '(', '<', '(', '[', '<']
# > Incomplete line 77: 13 ['(', '[', '[', '(', '(', '(', '(', '(', '<', '(', '<', '(', '[']
# > Incomplete line 77: 12 ['(', '[', '[', '(', '(', '(', '(', '(', '<', '(', '<', '(']
# > Incomplete line 77: 11 ['(', '[', '[', '(', '(', '(', '(', '(', '<', '(', '<']
# > Incomplete line 77: 10 ['(', '[', '[', '(', '(', '(', '(', '(', '<', '(']
# > Incomplete line 77: 9 ['(', '[', '[', '(', '(', '(', '(', '(', '<']
# > Incomplete line 77: 8 ['(', '[', '[', '(', '(', '(', '(', '(']
# > Incomplete line 77: 7 ['(', '[', '[', '(', '(', '(', '(']
# > Incomplete line 77: 6 ['(', '[', '[', '(', '(', '(']
# > Incomplete line 77: 5 ['(', '[', '[', '(', '(']
# > Incomplete line 77: 4 ['(', '[', '[', '(']
# > Incomplete line 77: 3 ['(', '[', '[']
# > Incomplete line 77: 2 ['(', '[']
# > Incomplete line 77: 1 ['(']
# Processing line: {({{{{<[<<(<<[[]()]{{}[]}>[<[]<>>[[]<>]]>(<<()<>>(<>())><([]<>)>})><<<({{}{}}<[]()>){{()()}[{}[]]}
# Processing line: [<[[({({[{[(({<>[]}{()<>})[({}())[[]()]]){[{()<>}(<>)](<<>>)}]}][(([[<{}()>]{([]{}){[]}}])[
# > Incomplete line 79: 11 ['[', '<', '[', '[', '(', '{', '(', '{', '[', '(', '[']
# > Incomplete line 79: 10 ['[', '<', '[', '[', '(', '{', '(', '{', '[', '(']
# > Incomplete line 79: 9 ['[', '<', '[', '[', '(', '{', '(', '{', '[']
# > Incomplete line 79: 8 ['[', '<', '[', '[', '(', '{', '(', '{']
# > Incomplete line 79: 7 ['[', '<', '[', '[', '(', '{', '(']
# > Incomplete line 79: 6 ['[', '<', '[', '[', '(', '{']
# > Incomplete line 79: 5 ['[', '<', '[', '[', '(']
# > Incomplete line 79: 4 ['[', '<', '[', '[']
# > Incomplete line 79: 3 ['[', '<', '[']
# > Incomplete line 79: 2 ['[', '<']
# > Incomplete line 79: 1 ['[']
# Processing line: (<{[<({[<<{{(<{}<>><<>{}>)[[{}()][{}[]]]}<[{[][]}](([]{})(()[]))>}<([{<><>}[[][]]][<[]{}><[]{}>]}(<{()
# Processing line: [(<(<([[[[<(({()[]}<<>()>)[[()<>]({}<>)])>]]]{(([(<(()<>)[[]<>]>{[<>()]{<>{}}})({<()()>}<<<><>>
# > Incomplete line 81: 13 ['[', '(', '<', '(', '<', '(', '[', '{', '(', '(', '[', '(', '<']
# > Incomplete line 81: 12 ['[', '(', '<', '(', '<', '(', '[', '{', '(', '(', '[', '(']
# > Incomplete line 81: 11 ['[', '(', '<', '(', '<', '(', '[', '{', '(', '(', '[']
# > Incomplete line 81: 10 ['[', '(', '<', '(', '<', '(', '[', '{', '(', '(']
# > Incomplete line 81: 9 ['[', '(', '<', '(', '<', '(', '[', '{', '(']
# > Incomplete line 81: 8 ['[', '(', '<', '(', '<', '(', '[', '{']
# > Incomplete line 81: 7 ['[', '(', '<', '(', '<', '(', '[']
# > Incomplete line 81: 6 ['[', '(', '<', '(', '<', '(']
# > Incomplete line 81: 5 ['[', '(', '<', '(', '<']
# > Incomplete line 81: 4 ['[', '(', '<', '(']
# > Incomplete line 81: 3 ['[', '(', '<']
# > Incomplete line 81: 2 ['[', '(']
# > Incomplete line 81: 1 ['[']
# Processing line: <(<[<{([<[{{<{()}[<><>]>(<()[]>(<><>))}[[<{}{}><[][]>]<((){})[<><>]>]}(((<[][]><[]{}>)[[{}{}]{()[]}]){[(()()
# > Incomplete line 82: 14 ['<', '(', '<', '[', '<', '{', '(', '[', '<', '[', '(', '{', '[', '(']
# > Incomplete line 82: 13 ['<', '(', '<', '[', '<', '{', '(', '[', '<', '[', '(', '{', '[']
# > Incomplete line 82: 12 ['<', '(', '<', '[', '<', '{', '(', '[', '<', '[', '(', '{']
# > Incomplete line 82: 11 ['<', '(', '<', '[', '<', '{', '(', '[', '<', '[', '(']
# > Incomplete line 82: 10 ['<', '(', '<', '[', '<', '{', '(', '[', '<', '[']
# > Incomplete line 82: 9 ['<', '(', '<', '[', '<', '{', '(', '[', '<']
# > Incomplete line 82: 8 ['<', '(', '<', '[', '<', '{', '(', '[']
# > Incomplete line 82: 7 ['<', '(', '<', '[', '<', '{', '(']
# > Incomplete line 82: 6 ['<', '(', '<', '[', '<', '{']
# > Incomplete line 82: 5 ['<', '(', '<', '[', '<']
# > Incomplete line 82: 4 ['<', '(', '<', '[']
# > Incomplete line 82: 3 ['<', '(', '<']
# > Incomplete line 82: 2 ['<', '(']
# > Incomplete line 82: 1 ['<']
# Processing line: ({<[<[{({{{(({{}<>}{<>[]})<{()[]}<{}{}>>)[((()<>)<<><>>]<[{}]<<><>>>]}[({[{}()][[]{}]}[[<><
# Processing line: [[(({[{[[<{[{({}())<<>[]>}{{{}[]}<(){}>}]{<[(){}]<{}<>]>}}([{{()[]}<<>()>}([()[]]<[]>)][<([]<>)[[]{
# Processing line: [<(<((({[[{([{<>[]}<<>()>]([[]()]))}]([(<{()[]>[{}{}]><{()()}<()[]>>)](<<[()[]]{<><>}>[<()[]>(<
# Processing line: ({({[<{<(<(([[[]{}]({}<>)])<{{{}{}}<{}{}>}{{{}<>}[{}()]}>)((<[<><>][(){}]><[{}<>](()())>)({{<
# > Incomplete line 86: 15 ['(', '{', '(', '{', '[', '<', '{', '<', '(', '<', '(', '(', '{', '{', '<']
# > Incomplete line 86: 14 ['(', '{', '(', '{', '[', '<', '{', '<', '(', '<', '(', '(', '{', '{']
# > Incomplete line 86: 13 ['(', '{', '(', '{', '[', '<', '{', '<', '(', '<', '(', '(', '{']
# > Incomplete line 86: 12 ['(', '{', '(', '{', '[', '<', '{', '<', '(', '<', '(', '(']
# > Incomplete line 86: 11 ['(', '{', '(', '{', '[', '<', '{', '<', '(', '<', '(']
# > Incomplete line 86: 10 ['(', '{', '(', '{', '[', '<', '{', '<', '(', '<']
# > Incomplete line 86: 9 ['(', '{', '(', '{', '[', '<', '{', '<', '(']
# > Incomplete line 86: 8 ['(', '{', '(', '{', '[', '<', '{', '<']
# > Incomplete line 86: 7 ['(', '{', '(', '{', '[', '<', '{']
# > Incomplete line 86: 6 ['(', '{', '(', '{', '[', '<']
# > Incomplete line 86: 5 ['(', '{', '(', '{', '[']
# > Incomplete line 86: 4 ['(', '{', '(', '{']
# > Incomplete line 86: 3 ['(', '{', '(']
# > Incomplete line 86: 2 ['(', '{']
# > Incomplete line 86: 1 ['(']
# Processing line: [{({({(<(<{({<<>[]><{}>}<<{}{}>{<>{}}>)(<[{}[]]([]())>{<(){}>{<><>}})}<{[{<>}{[]{}}]([{}{}]<<><>>)
# > Incomplete line 87: 12 ['[', '{', '(', '{', '(', '{', '(', '<', '(', '<', '<', '{']
# > Incomplete line 87: 11 ['[', '{', '(', '{', '(', '{', '(', '<', '(', '<', '<']
# > Incomplete line 87: 10 ['[', '{', '(', '{', '(', '{', '(', '<', '(', '<']
# > Incomplete line 87: 9 ['[', '{', '(', '{', '(', '{', '(', '<', '(']
# > Incomplete line 87: 8 ['[', '{', '(', '{', '(', '{', '(', '<']
# > Incomplete line 87: 7 ['[', '{', '(', '{', '(', '{', '(']
# > Incomplete line 87: 6 ['[', '{', '(', '{', '(', '{']
# > Incomplete line 87: 5 ['[', '{', '(', '{', '(']
# > Incomplete line 87: 4 ['[', '{', '(', '{']
# > Incomplete line 87: 3 ['[', '{', '(']
# > Incomplete line 87: 2 ['[', '{']
# > Incomplete line 87: 1 ['[']
# Processing line: ({{[({[<[<({[[[]{}](()())])<{<(){}>[()()]}<[<>()][(){}]>>)>({<<[[][]]<<><>>><<()[]>>><<<()[]>{[]()}
# Processing line: ({({{[[{((([{({}()){<>()}}]([[<>{}]<()[]>][[()]<[]<>>]))))}]]}[<({[<<{<[<>()]<<>{}>}<<{}{}>[<>()]>}([(()
# Processing line: [[{([{(<[{((({(){}])(<{}<>>[<>{}]))<<(<>())<[]{}>><(()[])<()[]>>>)([({<><>}<<>{}>)({<>{}}(<>{}))])}]>(
# Processing line: ([<<[<[[({{[[({}{}){()<>]]{[[]<>]}]({<()()>}{<[][]>})}})]({<{({[{}[]][()[]]}[{{}{}}{(){}}])<([[][]]{<>{}})
# Processing line: [{[{[({<([{[({()<>}{{}{}})<<[]{}>>][({{}[]}[()[]])[({}{})<<>{}>]]}]{{{<([]())(<>[])><<[]()>({}{})>}}((<<(){}>
# > Incomplete line 92: 13 ['[', '{', '[', '{', '[', '(', '{', '<', '(', '{', '(', '(', '<']
# > Incomplete line 92: 12 ['[', '{', '[', '{', '[', '(', '{', '<', '(', '{', '(', '(']
# > Incomplete line 92: 11 ['[', '{', '[', '{', '[', '(', '{', '<', '(', '{', '(']
# > Incomplete line 92: 10 ['[', '{', '[', '{', '[', '(', '{', '<', '(', '{']
# > Incomplete line 92: 9 ['[', '{', '[', '{', '[', '(', '{', '<', '(']
# > Incomplete line 92: 8 ['[', '{', '[', '{', '[', '(', '{', '<']
# > Incomplete line 92: 7 ['[', '{', '[', '{', '[', '(', '{']
# > Incomplete line 92: 6 ['[', '{', '[', '{', '[', '(']
# > Incomplete line 92: 5 ['[', '{', '[', '{', '[']
# > Incomplete line 92: 4 ['[', '{', '[', '{']
# > Incomplete line 92: 3 ['[', '{', '[']
# > Incomplete line 92: 2 ['[', '{']
# > Incomplete line 92: 1 ['[']
# Processing line: (<(<{({{<{[{([{}()]{(){}})[[<>{}](<><>)]})(<[{{}()}]<[[][]]{()<>}>><{{[]<>}{<>()}}{<{}<>>[[]<>]}>)}>}[[<(
# 1870887234
